# %%
#Mainly used for computer Vision
#Object Detection
#Built in c/c++

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-ff17a021-3ee4-4579-b760-99b1009708d0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ff17a021-3ee4-4579-b760-99b1009708d0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import cv2
import numpy

# %%
image=cv2.imread('website.jpg')

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=1020x510 at 0x7FF385CDCC90>

# %%
cv2.imwrite('saved.jpg',image)
# Out:
# True

# %%
image.shape
# Out:
# (510, 1020, 3)

# %%
#510 rows,1020 columns,3 channels

# %%
#Processing of gray scale is very fast
grey=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

# %%
cv2_imshow(grey)
# Out:
# <PIL.Image.Image image mode=L size=1020x510 at 0x7FF385C62550>

# %%
#Resizing image

# %%
re=cv2.resize(image,(400,400))
cv2_imshow(re)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7FF385CE2D10>

# %%
#Displaying Text
dt=cv2.putText(image,'OpenCV',(400,400),cv2.FONT_HERSHEY_COMPLEX,4,(255,0,0),2)

# %%
cv2_imshow(dt)
# Out:
# <PIL.Image.Image image mode=RGB size=1020x510 at 0x7FF385CE7610>

# %%
#Drawing shapes on image
l=cv2.line(image,(400,450),(500,450),(0,0,512),5)
cv2_imshow(l)
# Out:
# <PIL.Image.Image image mode=RGB size=1020x510 at 0x7FF385C57B10>

# %%
#Circle
c=cv2.circle(image,(630,200),80,(0,0,255),5)
cv2_imshow(c)
# Out:
# <PIL.Image.Image image mode=RGB size=1020x510 at 0x7FF386D50D90>

# %%
#Capturing video
cap=cv2.VideoCapture(0)
while(True):
  ret , frame=cap.read()
  cv2_imshow(frame)
  if cv2.waitKey(1) & 0xFF==ord('q'):
    break
    abc.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-69294cecf984> in <module>
#       3 while(True):
#       4   ret , frame=cap.read()
# ----> 5   cv2_imshow(frame)
#       6   if cv2.waitKey(1) & 0xFF==ord('q'):
#       7     break
#
# /usr/local/lib/python3.7/dist-packages/google/colab/patches/__init__.py in cv2_imshow(a)
#      16       image.
#      17   """
# ---> 18   a = a.clip(0, 255).astype('uint8')
#      19   # cv2 stores colors as BGR; convert to RGB
#      20   if a.ndim == 3:
#
# AttributeError: 'NoneType' object has no attribute 'clip'
